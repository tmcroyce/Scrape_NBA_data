# %% [markdown]
# ## Selenium Web Browsing

# %% [markdown]
# Two Helpful Tutorials:
# - #1 tutorial is: https://www.youtube.com/watch?v=pUUhvJvs-R4
# - #2 The nba.com tutorial is: https://www.youtube.com/watch?v=fAW6AxMHego

# %%
#pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# ## Enter selections to download correct data:
#  1. Go to https://www.nba.com/stats/teams/traditional/?sort=W_PCT&dir=-1&Season=2021-22&SeasonType=Regular%20Season
#  2. Select URL of the data you want by browsing around.
#  3. Enter Selections for file naming
#  4. Let er' rip. This will download the past 5 seasons of whatever data you want.

# %%
url =                  #[ENTER URL HERE]
pathy =                #[ENTER YOUR INITIAL PATH HERE] 

data_type = ''          #Describe the data. 
teams_or_players = 'teams' #Is the data team or player data?
season_type = 'playoffs'   # Is the data from playoffs or regular season?

# %%
driver = webdriver.Chrome()

# %%
# Mess with these to get different
reg_season= 'Regular%20Season'
playoffs = 'Playoffs'
teams = 'teams'
players = 'players'

#players and Team data types
trad = 'traditional'
adv = 'advanced'
misc = 'misc'
scoring = 'scoring'
usage = 'usage'
opp = 'opponent'
defense = 'defense'

#Teams Data Types
gen = 'general'
clutch = 'clutch'
tracking = 'tracking'
def_dash = 'defensedashboard'
shot_dash = 'shotdashboard'
boxes = 'boxscores'
adv_boxes = 'advancedboxscores'
opp_shooting = 'opponentshooting'
hustle = 'hustle'
boxouts = 'boxouts'
advlead = 'advancedleaders'
hustlead = 'hustleleaders'

#---- playtypes, just enter as data types
iso = 'isolation'
trans = 'transition'
ball = 'ball-handler' #pick and roll ball handler
roll = 'roll-man'
post = 'playtype-post-up'
spot = 'spot-up'
handoff = 'hand-off'
cut = 'cut'
offsc = 'off-screen'
put_backs = 'putbacks'

playtypes = ['isolation', 'transition', 'ball-handler','roll-man','playtype-post-up','spot-up','hand-off','cut', 'off-screen','putbacks' ]

# %%
driver.get(sup_url)

# %%
driver = webdriver.Chrome()
x_2020 = '/html/body/main/div/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[2]'
x_2019 = '/html/body/main/div/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[3]'
x_2018 = '/html/body/main/div/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[4]'
x_2017 = '/html/body/main/div/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[5]'
x_2016 = '/html/body/main/div/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[6]'

# %%
#ALL IN ONE
year = '2021'
src = driver.page_source
parser = BeautifulSoup(src, "lxml")
table = parser.find("div", attrs = {"class":"nba-stat-table__overflow"}) #This finds the div within the class.

#find headers and grab them
headers = table.findAll('th') # All headers are under th in nba.com data
headerlist = [h.text.strip() for h in headers[0:]] 
headerlist = [a for a in headerlist if not 'RANK' in a]

#find rows and grab them
row_names = table.findAll('a') 
row_list = [b.text.strip() for b in row_names[0:]] 

#find row data and grab it
rows = table.findAll('tr')[0:]
player_stats = [[td.getText().strip() for td in rows[i].findAll('td')[0:]] for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headerlist)

ti = chr(92)
pathywath = pathy +ti + year + '-' + season_type + '-' + teams_or_players + '-' + data_type + 'defense.xlsx'

stats = stats.drop(0,0)
stats

pd.DataFrame.to_excel(stats, pathywath)
#--------------------------------------------------------------------------------------
# select year
year = '2020'

# Select Year, then RUN
driver.find_element(by=By.XPATH, value=x_2020).click()
time.sleep(2)

#
src = driver.page_source
parser = BeautifulSoup(src, "lxml")
table = parser.find("div", attrs = {"class":"nba-stat-table__overflow"})

#find headers and grab them
headers = table.findAll('th')
headerlist = [h.text.strip() for h in headers[0:]] 
headerlist = [a for a in headerlist if not 'RANK' in a]

#find rows and grab them
row_names = table.findAll('a') 
row_list = [b.text.strip() for b in row_names[0:]] 

#find row data and grab it
rows = table.findAll('tr')[0:]
player_stats = [[td.getText().strip() for td in rows[i].findAll('td')[0:]] for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headerlist)

ti = chr(92)
pathywath = pathy +ti + year + '-' + season_type + '-' + teams_or_players + '-' + data_type + 'defense.xlsx'

stats = stats.drop(0,0)

pd.DataFrame.to_excel(stats, pathywath)
#--------------------------------------------------------------------------------------
# select year
year = '2019'

# Select Year, then RUN
driver.find_element(by=By.XPATH, value=x_2019).click()
time.sleep(2)

#
src = driver.page_source
parser = BeautifulSoup(src, "lxml")
table = parser.find("div", attrs = {"class":"nba-stat-table__overflow"})

#find headers and grab them
headers = table.findAll('th')
headerlist = [h.text.strip() for h in headers[0:]] 
headerlist = [a for a in headerlist if not 'RANK' in a]

#find rows and grab them
row_names = table.findAll('a') 
row_list = [b.text.strip() for b in row_names[0:]] 

#find row data and grab it
rows = table.findAll('tr')[0:]
player_stats = [[td.getText().strip() for td in rows[i].findAll('td')[0:]] for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headerlist)

ti = chr(92)
pathywath = pathy +ti + year + '-' + season_type + '-' + teams_or_players + '-' + data_type + 'defense.xlsx'

stats = stats.drop(0,0)

pd.DataFrame.to_excel(stats, pathywath)
# ------------------------------------------------------------------------------------------------
# select year
year = '2018'

# Select Year, then RUN
driver.find_element(by=By.XPATH, value=x_2018).click()
time.sleep(2)

#
src = driver.page_source
parser = BeautifulSoup(src, "lxml")
table = parser.find("div", attrs = {"class":"nba-stat-table__overflow"})

#find headers and grab them
headers = table.findAll('th')
headerlist = [h.text.strip() for h in headers[0:]] 
headerlist = [a for a in headerlist if not 'RANK' in a]

#find rows and grab them
row_names = table.findAll('a') 
row_list = [b.text.strip() for b in row_names[0:]] 

#find row data and grab it
rows = table.findAll('tr')[0:]
player_stats = [[td.getText().strip() for td in rows[i].findAll('td')[0:]] for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headerlist)

ti = chr(92)
pathywath = pathy +ti + year + '-' + season_type + '-' + teams_or_players + '-' + data_type + 'defense.xlsx'

stats = stats.drop(0,0)

pd.DataFrame.to_excel(stats, pathywath)
# -------------------------------------------------------------------------------------------
# select year
year = '2017'

# Select Year, then RUN
driver.find_element(by=By.XPATH, value=x_2017).click()
time.sleep(2)

#
src = driver.page_source
parser = BeautifulSoup(src, "lxml")
table = parser.find("div", attrs = {"class":"nba-stat-table__overflow"})

#find headers and grab them
headers = table.findAll('th')
headerlist = [h.text.strip() for h in headers[0:]] 
headerlist = [a for a in headerlist if not 'RANK' in a]

#find rows and grab them
row_names = table.findAll('a') 
row_list = [b.text.strip() for b in row_names[0:]] 

#find row data and grab it
rows = table.findAll('tr')[0:]
player_stats = [[td.getText().strip() for td in rows[i].findAll('td')[0:]] for i in range(len(rows))]
stats = pd.DataFrame(player_stats, columns = headerlist)

ti = chr(92)
pathywath = pathy +ti + year + '-' + season_type + '-' + teams_or_players + '-' + data_type + 'defense.xlsx'

stats = stats.drop(0,0)

pd.DataFrame.to_excel(stats, pathywath)
